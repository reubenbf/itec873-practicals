# %% [markdown]
# _This notebook contains all the sample code and solutions to the exercises in chapter 10._

# %% [markdown]
# **Chapter 10 – Introduction to Artificial Neural Networks**

# %% [markdown]
# # Setup

# %% [markdown]
# First, let's make sure this notebook works well in both python 2 and 3, import a few common modules, ensure MatplotLib plots figures inline and prepare a function to save the figures:

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "ann"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %% [markdown]
# # Perceptrons

# %% [markdown]
# **Note**: we set `max_iter` and `tol` explicitly to avoid warnings about the fact that their default value will change in future versions of Scikit-Learn.

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:, (2, 3)]  # petal length, petal width
y = (iris.target == 0).astype(np.int)

per_clf = Perceptron(max_iter=100, tol=-np.infty, random_state=42)
per_clf.fit(X, y)

y_pred = per_clf.predict([[2, 0.5]])

# %%
y_pred
# Out:
# array([1])

# %%
a = -per_clf.coef_[0][0] / per_clf.coef_[0][1]
b = -per_clf.intercept_ / per_clf.coef_[0][1]

axes = [0, 5, 0, 2]

x0, x1 = np.meshgrid(
        np.linspace(axes[0], axes[1], 500).reshape(-1, 1),
        np.linspace(axes[2], axes[3], 200).reshape(-1, 1),
    )
X_new = np.c_[x0.ravel(), x1.ravel()]
y_predict = per_clf.predict(X_new)
zz = y_predict.reshape(x0.shape)

plt.figure(figsize=(10, 4))
plt.plot(X[y==0, 0], X[y==0, 1], "bs", label="Not Iris-Setosa")
plt.plot(X[y==1, 0], X[y==1, 1], "yo", label="Iris-Setosa")

plt.plot([axes[0], axes[1]], [a * axes[0] + b, a * axes[1] + b], "k-", linewidth=3)
from matplotlib.colors import ListedColormap
custom_cmap = ListedColormap(['#9898ff', '#fafab0'])

plt.contourf(x0, x1, zz, cmap=custom_cmap)
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(loc="lower right", fontsize=14)
plt.axis(axes)

# save_fig("perceptron_iris_plot")
plt.show()

# %% [markdown]
# # Activation functions

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def relu(z):
    return np.maximum(0, z)

def derivative(f, z, eps=0.000001):
    return (f(z + eps) - f(z - eps))/(2 * eps)

# %%
z = np.linspace(-5, 5, 200)

plt.figure(figsize=(11,4))

plt.subplot(121)
plt.plot(z, np.sign(z), "r-", linewidth=1, label="Step")
plt.plot(z, sigmoid(z), "g--", linewidth=2, label="Sigmoid")
plt.plot(z, np.tanh(z), "b-", linewidth=2, label="Tanh")
plt.plot(z, relu(z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
plt.legend(loc="center right", fontsize=14)
plt.title("Activation functions", fontsize=14)
plt.axis([-5, 5, -1.2, 1.2])

plt.subplot(122)
plt.plot(z, derivative(np.sign, z), "r-", linewidth=1, label="Step")
plt.plot(0, 0, "ro", markersize=5)
plt.plot(0, 0, "rx", markersize=10)
plt.plot(z, derivative(sigmoid, z), "g--", linewidth=2, label="Sigmoid")
plt.plot(z, derivative(np.tanh, z), "b-", linewidth=2, label="Tanh")
plt.plot(z, derivative(relu, z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
#plt.legend(loc="center right", fontsize=14)
plt.title("Derivatives", fontsize=14)
plt.axis([-5, 5, -0.2, 1.2])

# save_fig("activation_functions_plot")
plt.show()

# %%
def heaviside(z):
    return (z >= 0).astype(z.dtype)

def mlp_xor(x1, x2, activation=heaviside):
    return activation(-activation(x1 + x2 - 1.5) + activation(x1 + x2 - 0.5) - 0.5)

# %%
x1s = np.linspace(-0.2, 1.2, 100)
x2s = np.linspace(-0.2, 1.2, 100)
x1, x2 = np.meshgrid(x1s, x2s)

z1 = mlp_xor(x1, x2, activation=heaviside)
z2 = mlp_xor(x1, x2, activation=sigmoid)
z3 = mlp_xor(x1, x2, activation=relu)
#z2 = mlp_xor(x1, x2, activation=sigmoid)

plt.figure(figsize=(20,8))

plt.subplot(221)
plt.contourf(x1, x2, z1)
plt.plot([0, 1], [0, 1], "gs", markersize=20)
plt.plot([0, 1], [1, 0], "y^", markersize=20)
plt.title("Activation function: heaviside", fontsize=14)
plt.grid(True)

plt.subplot(222)
plt.contourf(x1, x2, z2)
plt.plot([0, 1], [0, 1], "gs", markersize=20)
plt.plot([0, 1], [1, 0], "y^", markersize=20)
plt.title("Activation function: sigmoid", fontsize=14)
plt.grid(True)

plt.subplot(223)
plt.contourf(x1, x2, z3)
plt.plot([0, 1], [0, 1], "gs", markersize=20)
plt.plot([0, 1], [1, 0], "y^", markersize=20)
plt.title("Activation function: relu", fontsize=14)
plt.grid(True)

plt.subplot(224)
plt.contourf(x1, x2, z3)
plt.plot([0, 1], [0, 1], "gs", markersize=20)
plt.plot([0, 1], [1, 0], "y^", markersize=20)
plt.title("Activation function: relu", fontsize=14)
plt.grid(True)

# %% [markdown]
# # FNN for MNIST

# %% [markdown]
# ## Using the Estimator API (formerly `tf.contrib.learn`)

# %%
import tensorflow as tf

# %% [markdown]
# **Warning**: `tf.examples.tutorials.mnist` is deprecated. We will use `tf.keras.datasets.mnist` instead. Moreover, the `tf.contrib.learn` API was promoted to `tf.estimators` and `tf.feature_columns`, and it has changed considerably. In particular, there is no `infer_real_valued_columns_from_input()` function or `SKCompat` class.

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
feature_cols = [tf.feature_column.numeric_column("X", shape=[28 * 28])]
dnn_clf = tf.estimator.DNNClassifier(hidden_units=[300,100], n_classes=10,
                                     feature_columns=feature_cols)

input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_train}, y=y_train, num_epochs=40, batch_size=50, shuffle=True)
dnn_clf.train(input_fn=input_fn)
# Out:
# INFO:tensorflow:global_step/sec: 248.805
# INFO:tensorflow:loss = 3.2632754, step = 2801 (0.405 sec)
# INFO:tensorflow:global_step/sec: 242.295
# INFO:tensorflow:loss = 3.3140004, step = 2901 (0.411 sec)
# INFO:tensorflow:global_step/sec: 233.196
# INFO:tensorflow:loss = 2.6615674, step = 3001 (0.428 sec)
# INFO:tensorflow:global_step/sec: 263.637
# INFO:tensorflow:loss = 2.8040285, step = 3101 (0.379 sec)
# INFO:tensorflow:global_step/sec: 257.132
# INFO:tensorflow:loss = 1.0311325, step = 3201 (0.389 sec)
# INFO:tensorflow:global_step/sec: 246.803
# INFO:tensorflow:loss = 2.6979012, step = 3301 (0.405 sec)
# INFO:tensorflow:global_step/sec: 253.05
# INFO:tensorflow:loss = 4.0715914, step = 3401 (0.395 sec)
# INFO:tensorflow:global_step/sec: 239.363
# INFO:tensorflow:loss = 2.259076, step = 3501 (0.418 sec)
# INFO:tensorflow:global_step/sec: 248
# INFO:tensorflow:loss = 1.944988, step = 3601 (0.404 sec)
# INFO:tensorflow:global_step/sec: 256.486
# INFO:tensorflow:loss = 1.5774875, step = 3701 (0.388 sec)
# INFO:tensorflow:global_step/sec: 252.556
# INFO:tensorflow:loss = 0.58597064, step = 3801 (0.396 sec)
# INFO:tensorflow:global_step/sec: 244.309
# INFO:tensorflow:loss = 0.9414134, step = 3901 (0.411 sec)
# INFO:tensorflow:global_step/sec: 226.971
# INFO:tensorflow:loss = 6.1261425, step = 4001 (0.439 sec)
# INFO:tensorflow:global_step/sec: 242.222
# INFO:tensorflow:loss = 1.6167815, step = 4101 (0.413 sec)
# INFO:tensorflow:global_step/sec: 244.289
# INFO:tensorflow:loss = 0.682361, step = 4201 (0.409 sec)
# INFO:tensorflow:global_step/sec: 228.811
# INFO:tensorflow:loss = 1.7604215, step = 4301 (0.439 sec)
# INFO:tensorflow:global_step/sec: 238.359
# INFO:tensorflow:loss = 3.605583, step = 4401 (0.417 sec)
# INFO:tensorflow:global_step/sec: 236.793
# INFO:tensorflow:loss = 0.14158365, step = 4501 (0.422 sec)
# INFO:tensorflow:global_step/sec: 239.423
# INFO:tensorflow:loss = 3.3258312, step = 4601 (0.418 sec)
# INFO:tensorflow:global_step/sec: 231.194
# INFO:tensorflow:loss = 1.9253218, step = 4701 (0.434 sec)
# INFO:tensorflow:global_step/sec: 233.796
# INFO:tensorflow:loss = 1.2877196, step = 4801 (0.426 sec)
# INFO:tensorflow:global_step/sec: 222.943
# INFO:tensorflow:loss = 0.9203481, step = 4901 (0.448 sec)
# INFO:tensorflow:global_step/sec: 244.67
# INFO:tensorflow:loss = 4.131885, step = 5001 (0.409 sec)
# INFO:tensorflow:global_step/sec: 246.382
# INFO:tensorflow:loss = 2.6010125, step = 5101 (0.406 sec)
# INFO:tensorflow:global_step/sec: 246.764
# INFO:tensorflow:loss = 3.475404, step = 5201 (0.405 sec)
# INFO:tensorflow:global_step/sec: 248.51
# INFO:tensorflow:loss = 0.77636737, step = 5301 (0.405 sec)
# INFO:tensorflow:global_step/sec: 241.536
# INFO:tensorflow:loss = 0.22068565, step = 5401 (0.412 sec)
# INFO:tensorflow:global_step/sec: 251.826
# INFO:tensorflow:loss = 1.7857311, step = 5501 (0.396 sec)
# INFO:tensorflow:global_step/sec: 245.034
# INFO:tensorflow:loss = 0.6161025, step = 5601 (0.408 sec)
# INFO:tensorflow:global_step/sec: 238.138
# INFO:tensorflow:loss = 0.36203685, step = 5701 (0.420 sec)
# INFO:tensorflow:global_step/sec: 243.86
# INFO:tensorflow:loss = 0.48552597, step = 5801 (0.409 sec)
# INFO:tensorflow:global_step/sec: 247.339
# INFO:tensorflow:loss = 0.1602817, step = 5901 (0.407 sec)
# INFO:tensorflow:global_step/sec: 255.32
# INFO:tensorflow:loss = 0.91258025, step = 6001 (0.389 sec)
# INFO:tensorflow:global_step/sec: 260.342
# INFO:tensorflow:loss = 0.9760896, step = 6101 (0.384 sec)
# INFO:tensorflow:global_step/sec: 260.512
# INFO:tensorflow:loss = 0.25987923, step = 6201 (0.384 sec)
# INFO:tensorflow:global_step/sec: 247.467
# INFO:tensorflow:loss = 1.4062028, step = 6301 (0.404 sec)
# INFO:tensorflow:global_step/sec: 237.374
# INFO:tensorflow:loss = 0.6163388, step = 6401 (0.421 sec)
# INFO:tensorflow:global_step/sec: 246.185
# INFO:tensorflow:loss = 0.46366036, step = 6501 (0.407 sec)
# INFO:tensorflow:global_step/sec: 254.515
# INFO:tensorflow:loss = 9.786855, step = 6601 (0.393 sec)
# INFO:tensorflow:global_step/sec: 250.106
# INFO:tensorflow:loss = 0.073547356, step = 6701 (0.399 sec)
# INFO:tensorflow:global_step/sec: 233.042
# INFO:tensorflow:loss = 1.544784, step = 6801 (0.429 sec)
# INFO:tensorflow:global_step/sec: 244.3
# INFO:tensorflow:loss = 0.043174237, step = 6901 (0.409 sec)
# INFO:tensorflow:global_step/sec: 249.212
# INFO:tensorflow:loss = 0.47353345, step = 7001 (0.401 sec)
# INFO:tensorflow:global_step/sec: 247.245
# INFO:tensorflow:loss = 0.20238616, step = 7101 (0.405 sec)
# INFO:tensorflow:global_step/sec: 245.688
# INFO:tensorflow:loss = 0.119615, step = 7201 (0.407 sec)
# INFO:tensorflow:global_step/sec: 240.781
# INFO:tensorflow:loss = 5.8632984, step = 7301 (0.415 sec)
# INFO:tensorflow:global_step/sec: 227.108
# INFO:tensorflow:loss = 0.7144698, step = 7401 (0.440 sec)
# INFO:tensorflow:global_step/sec: 236.523
# INFO:tensorflow:loss = 0.32027793, step = 7501 (0.422 sec)
# INFO:tensorflow:global_step/sec: 242.602
# INFO:tensorflow:loss = 1.8322486, step = 7601 (0.412 sec)
# INFO:tensorflow:global_step/sec: 245.117
# INFO:tensorflow:loss = 1.0093694, step = 7701 (0.408 sec)
# INFO:tensorflow:global_step/sec: 250.537
# INFO:tensorflow:loss = 1.1054628, step = 7801 (0.399 sec)
# INFO:tensorflow:global_step/sec: 248.031
# INFO:tensorflow:loss = 0.55972433, step = 7901 (0.403 sec)
# INFO:tensorflow:global_step/sec: 250.704
# INFO:tensorflow:loss = 0.22973979, step = 8001 (0.399 sec)
# INFO:tensorflow:global_step/sec: 249.391
# INFO:tensorflow:loss = 0.22336751, step = 8101 (0.404 sec)
# INFO:tensorflow:global_step/sec: 253.245
# INFO:tensorflow:loss = 0.2799379, step = 8201 (0.394 sec)
# INFO:tensorflow:global_step/sec: 248.1
# INFO:tensorflow:loss = 1.1426848, step = 8301 (0.400 sec)
# INFO:tensorflow:global_step/sec: 247.121
# INFO:tensorflow:loss = 0.19871382, step = 8401 (0.407 sec)
# INFO:tensorflow:global_step/sec: 252.9
# INFO:tensorflow:loss = 1.782929, step = 8501 (0.393 sec)
# INFO:tensorflow:global_step/sec: 251.439
# INFO:tensorflow:loss = 0.71559775, step = 8601 (0.397 sec)
# INFO:tensorflow:global_step/sec: 259.218
# INFO:tensorflow:loss = 0.9492582, step = 8701 (0.386 sec)
# INFO:tensorflow:global_step/sec: 255.8
# INFO:tensorflow:loss = 0.6038555, step = 8801 (0.391 sec)
# INFO:tensorflow:global_step/sec: 246.033
# INFO:tensorflow:loss = 0.10007736, step = 8901 (0.406 sec)
# INFO:tensorflow:global_step/sec: 241.585
# INFO:tensorflow:loss = 0.16287372, step = 9001 (0.415 sec)
# INFO:tensorflow:global_step/sec: 249.39
# INFO:tensorflow:loss = 0.46750483, step = 9101 (0.400 sec)
# INFO:tensorflow:global_step/sec: 250.419
# INFO:tensorflow:loss = 0.02743237, step = 9201 (0.399 sec)
# INFO:tensorflow:global_step/sec: 242.273
# INFO:tensorflow:loss = 0.04364274, step = 9301 (0.412 sec)
# INFO:tensorflow:global_step/sec: 250.469
# INFO:tensorflow:loss = 0.1798663, step = 9401 (0.400 sec)
# INFO:tensorflow:global_step/sec: 252.019
# INFO:tensorflow:loss = 0.16188815, step = 9501 (0.397 sec)
# INFO:tensorflow:global_step/sec: 250.882
# INFO:tensorflow:loss = 0.59297895, step = 9601 (0.400 sec)
# INFO:tensorflow:global_step/sec: 250.052
# INFO:tensorflow:loss = 1.3459193, step = 9701 (0.399 sec)
# INFO:tensorflow:global_step/sec: 264.159
# INFO:tensorflow:loss = 0.23135437, step = 9801 (0.379 sec)
# INFO:tensorflow:global_step/sec: 254.354
# INFO:tensorflow:loss = 0.12702145, step = 9901 (0.393 sec)
# INFO:tensorflow:global_step/sec: 234.765
# INFO:tensorflow:loss = 0.4705624, step = 10001 (0.426 sec)
# INFO:tensorflow:global_step/sec: 251.76
# INFO:tensorflow:loss = 1.2799177, step = 10101 (0.398 sec)
# INFO:tensorflow:global_step/sec: 252.925
# INFO:tensorflow:loss = 0.25955802, step = 10201 (0.395 sec)
# INFO:tensorflow:global_step/sec: 259.497
# INFO:tensorflow:loss = 0.41020745, step = 10301 (0.385 sec)
# INFO:tensorflow:global_step/sec: 246.609
# INFO:tensorflow:loss = 0.42366824, step = 10401 (0.405 sec)
# INFO:tensorflow:global_step/sec: 250.635
# INFO:tensorflow:loss = 0.9172955, step = 10501 (0.399 sec)
# INFO:tensorflow:global_step/sec: 248.712
# INFO:tensorflow:loss = 0.16946173, step = 10601 (0.402 sec)
# INFO:tensorflow:global_step/sec: 254.756
# INFO:tensorflow:loss = 0.032569427, step = 10701 (0.392 sec)
# INFO:tensorflow:global_step/sec: 248.698
# INFO:tensorflow:loss = 0.07395506, step = 10801 (0.402 sec)
# INFO:tensorflow:global_step/sec: 256.934
# INFO:tensorflow:loss = 0.5438844, step = 10901 (0.389 sec)
# INFO:tensorflow:global_step/sec: 257.975
# INFO:tensorflow:loss = 0.24368131, step = 11001 (0.391 sec)
# INFO:tensorflow:global_step/sec: 252.984
# INFO:tensorflow:loss = 0.13465059, step = 11101 (0.392 sec)
# INFO:tensorflow:global_step/sec: 255.205
# INFO:tensorflow:loss = 0.087712504, step = 11201 (0.392 sec)
# INFO:tensorflow:global_step/sec: 255.532
# INFO:tensorflow:loss = 0.15767686, step = 11301 (0.392 sec)
# INFO:tensorflow:global_step/sec: 248.686
# INFO:tensorflow:loss = 0.44276017, step = 11401 (0.402 sec)
# INFO:tensorflow:global_step/sec: 248.711
# INFO:tensorflow:loss = 0.33274752, step = 11501 (0.402 sec)
# INFO:tensorflow:global_step/sec: 238.182
# INFO:tensorflow:loss = 0.42740545, step = 11601 (0.419 sec)
# INFO:tensorflow:global_step/sec: 223.326
# INFO:tensorflow:loss = 0.21025895, step = 11701 (0.449 sec)
# INFO:tensorflow:global_step/sec: 229.414
# INFO:tensorflow:loss = 0.043415103, step = 11801 (0.435 sec)
# INFO:tensorflow:global_step/sec: 240.807
# INFO:tensorflow:loss = 1.7317549, step = 11901 (0.416 sec)
# INFO:tensorflow:global_step/sec: 239.344
# INFO:tensorflow:loss = 0.47993782, step = 12001 (0.417 sec)
# INFO:tensorflow:global_step/sec: 243.017
# INFO:tensorflow:loss = 0.21090424, step = 12101 (0.412 sec)
# INFO:tensorflow:global_step/sec: 240.775
# INFO:tensorflow:loss = 0.2330398, step = 12201 (0.415 sec)
# INFO:tensorflow:global_step/sec: 230.935
# INFO:tensorflow:loss = 0.55848116, step = 12301 (0.436 sec)
# INFO:tensorflow:global_step/sec: 239.781
# INFO:tensorflow:loss = 0.24544027, step = 12401 (0.414 sec)
# INFO:tensorflow:global_step/sec: 230.454
# INFO:tensorflow:loss = 0.08197227, step = 12501 (0.434 sec)
# INFO:tensorflow:global_step/sec: 255.778
# INFO:tensorflow:loss = 0.043552723, step = 12601 (0.391 sec)
# INFO:tensorflow:global_step/sec: 262.214
# INFO:tensorflow:loss = 0.3656549, step = 12701 (0.384 sec)
# INFO:tensorflow:global_step/sec: 237.796
# INFO:tensorflow:loss = 0.041893724, step = 12801 (0.418 sec)
# INFO:tensorflow:global_step/sec: 255.19
# INFO:tensorflow:loss = 0.39831972, step = 12901 (0.395 sec)
# INFO:tensorflow:global_step/sec: 242.26
# INFO:tensorflow:loss = 0.2460099, step = 13001 (0.410 sec)
# INFO:tensorflow:global_step/sec: 253.006
# INFO:tensorflow:loss = 0.24691644, step = 13101 (0.398 sec)
# INFO:tensorflow:global_step/sec: 242.363
# INFO:tensorflow:loss = 0.26903868, step = 13201 (0.410 sec)
# INFO:tensorflow:global_step/sec: 230.174
# INFO:tensorflow:loss = 0.13622165, step = 13301 (0.438 sec)
# INFO:tensorflow:global_step/sec: 243.443
# INFO:tensorflow:loss = 0.18474019, step = 13401 (0.408 sec)
# INFO:tensorflow:global_step/sec: 249.165
# INFO:tensorflow:loss = 0.08139518, step = 13501 (0.402 sec)
# INFO:tensorflow:global_step/sec: 258.659
# INFO:tensorflow:loss = 0.19102202, step = 13601 (0.386 sec)
# INFO:tensorflow:global_step/sec: 251.177
# INFO:tensorflow:loss = 0.91050225, step = 13701 (0.398 sec)
# INFO:tensorflow:global_step/sec: 234.63
# INFO:tensorflow:loss = 0.1954845, step = 13801 (0.429 sec)
# INFO:tensorflow:global_step/sec: 249.045
# INFO:tensorflow:loss = 0.027379451, step = 13901 (0.398 sec)
# INFO:tensorflow:global_step/sec: 253.189
# INFO:tensorflow:loss = 0.31185257, step = 14001 (0.396 sec)
# INFO:tensorflow:global_step/sec: 253.397
# INFO:tensorflow:loss = 0.17762755, step = 14101 (0.395 sec)
# INFO:tensorflow:global_step/sec: 253.347
# INFO:tensorflow:loss = 0.0027720383, step = 14201 (0.394 sec)
# INFO:tensorflow:global_step/sec: 238.069
# INFO:tensorflow:loss = 0.01023482, step = 14301 (0.419 sec)
# INFO:tensorflow:global_step/sec: 240.616
# INFO:tensorflow:loss = 0.13671307, step = 14401 (0.416 sec)
# INFO:tensorflow:global_step/sec: 250.974
# INFO:tensorflow:loss = 0.21888049, step = 14501 (0.401 sec)
# INFO:tensorflow:global_step/sec: 241.066
# INFO:tensorflow:loss = 0.5248811, step = 14601 (0.414 sec)
# INFO:tensorflow:global_step/sec: 257.26
# INFO:tensorflow:loss = 0.41538587, step = 14701 (0.386 sec)
# INFO:tensorflow:global_step/sec: 246.167
# INFO:tensorflow:loss = 0.029548606, step = 14801 (0.406 sec)
# INFO:tensorflow:global_step/sec: 256.299
# INFO:tensorflow:loss = 0.21843055, step = 14901 (0.390 sec)
# INFO:tensorflow:global_step/sec: 248.738
# INFO:tensorflow:loss = 0.17993137, step = 15001 (0.406 sec)
# INFO:tensorflow:global_step/sec: 236.575
# INFO:tensorflow:loss = 0.017513135, step = 15101 (0.419 sec)
# INFO:tensorflow:global_step/sec: 251.239
# INFO:tensorflow:loss = 0.2167475, step = 15201 (0.398 sec)
# INFO:tensorflow:global_step/sec: 243.244
# INFO:tensorflow:loss = 0.0064802626, step = 15301 (0.411 sec)
# INFO:tensorflow:global_step/sec: 266.064
# INFO:tensorflow:loss = 0.20340478, step = 15401 (0.380 sec)
# INFO:tensorflow:global_step/sec: 258.841
# INFO:tensorflow:loss = 0.22734249, step = 15501 (0.382 sec)
# INFO:tensorflow:global_step/sec: 254.24
# INFO:tensorflow:loss = 0.014853181, step = 15601 (0.394 sec)
# INFO:tensorflow:global_step/sec: 250.795
# INFO:tensorflow:loss = 0.010228864, step = 15701 (0.399 sec)
# INFO:tensorflow:global_step/sec: 238.574
# INFO:tensorflow:loss = 2.3339617, step = 15801 (0.419 sec)
# INFO:tensorflow:global_step/sec: 246.793
# INFO:tensorflow:loss = 0.07500277, step = 15901 (0.405 sec)
# INFO:tensorflow:global_step/sec: 242.83
# INFO:tensorflow:loss = 0.04911594, step = 16001 (0.412 sec)
# INFO:tensorflow:global_step/sec: 241.254
# INFO:tensorflow:loss = 0.023605995, step = 16101 (0.414 sec)
# INFO:tensorflow:global_step/sec: 245.531
# INFO:tensorflow:loss = 0.065519586, step = 16201 (0.410 sec)
# INFO:tensorflow:global_step/sec: 239.384
# INFO:tensorflow:loss = 0.09444242, step = 16301 (0.415 sec)
# INFO:tensorflow:global_step/sec: 244.053
# INFO:tensorflow:loss = 0.0056217476, step = 16401 (0.410 sec)
# INFO:tensorflow:global_step/sec: 253.524
# INFO:tensorflow:loss = 0.08418714, step = 16501 (0.394 sec)
# INFO:tensorflow:global_step/sec: 262.622
# INFO:tensorflow:loss = 0.098235905, step = 16601 (0.381 sec)
# INFO:tensorflow:global_step/sec: 251.763
# INFO:tensorflow:loss = 0.024874127, step = 16701 (0.397 sec)
# INFO:tensorflow:global_step/sec: 256.455
# INFO:tensorflow:loss = 0.109314136, step = 16801 (0.390 sec)
# INFO:tensorflow:global_step/sec: 257.087
# INFO:tensorflow:loss = 0.060498796, step = 16901 (0.389 sec)
# INFO:tensorflow:global_step/sec: 259.773
# INFO:tensorflow:loss = 0.032414943, step = 17001 (0.385 sec)
# INFO:tensorflow:global_step/sec: 258.207
# INFO:tensorflow:loss = 0.09010213, step = 17101 (0.387 sec)
# INFO:tensorflow:global_step/sec: 257.574
# INFO:tensorflow:loss = 0.007406138, step = 17201 (0.392 sec)
# INFO:tensorflow:global_step/sec: 238.494
# INFO:tensorflow:loss = 0.35677445, step = 17301 (0.415 sec)
# INFO:tensorflow:global_step/sec: 254.974
# INFO:tensorflow:loss = 0.0043916516, step = 17401 (0.392 sec)
# INFO:tensorflow:global_step/sec: 241.99
# INFO:tensorflow:loss = 0.31058207, step = 17501 (0.413 sec)
# INFO:tensorflow:global_step/sec: 233.391
# INFO:tensorflow:loss = 0.11119732, step = 17601 (0.429 sec)
# INFO:tensorflow:global_step/sec: 244.46
# INFO:tensorflow:loss = 0.11685818, step = 17701 (0.408 sec)
# INFO:tensorflow:global_step/sec: 244.251
# INFO:tensorflow:loss = 0.063181296, step = 17801 (0.413 sec)
# INFO:tensorflow:global_step/sec: 244.045
# INFO:tensorflow:loss = 0.06311989, step = 17901 (0.406 sec)
# INFO:tensorflow:global_step/sec: 235.123
# INFO:tensorflow:loss = 0.031568862, step = 18001 (0.427 sec)
# INFO:tensorflow:global_step/sec: 247.155
# INFO:tensorflow:loss = 0.012195587, step = 18101 (0.402 sec)
# INFO:tensorflow:global_step/sec: 244.377
# INFO:tensorflow:loss = 0.017227586, step = 18201 (0.409 sec)
# INFO:tensorflow:global_step/sec: 242.516
# INFO:tensorflow:loss = 0.16696896, step = 18301 (0.414 sec)
# INFO:tensorflow:global_step/sec: 245.829
# INFO:tensorflow:loss = 0.114180736, step = 18401 (0.405 sec)
# INFO:tensorflow:global_step/sec: 240.456
# INFO:tensorflow:loss = 0.05883965, step = 18501 (0.416 sec)
# INFO:tensorflow:global_step/sec: 251.784
# INFO:tensorflow:loss = 0.30967772, step = 18601 (0.397 sec)
# INFO:tensorflow:global_step/sec: 243.07
# INFO:tensorflow:loss = 0.10479158, step = 18701 (0.412 sec)
# INFO:tensorflow:global_step/sec: 249.178
# INFO:tensorflow:loss = 0.045600966, step = 18801 (0.401 sec)
# INFO:tensorflow:global_step/sec: 242.623
# INFO:tensorflow:loss = 0.11374257, step = 18901 (0.412 sec)
# INFO:tensorflow:global_step/sec: 245.098
# INFO:tensorflow:loss = 0.11772388, step = 19001 (0.408 sec)
# INFO:tensorflow:global_step/sec: 251.063
# INFO:tensorflow:loss = 0.05568953, step = 19101 (0.398 sec)
# INFO:tensorflow:global_step/sec: 242.398
# INFO:tensorflow:loss = 0.13978182, step = 19201 (0.415 sec)
# INFO:tensorflow:global_step/sec: 262.794
# INFO:tensorflow:loss = 0.10274236, step = 19301 (0.378 sec)
# INFO:tensorflow:global_step/sec: 250.926
# INFO:tensorflow:loss = 0.021262629, step = 19401 (0.398 sec)
# INFO:tensorflow:global_step/sec: 256.223
# INFO:tensorflow:loss = 0.48309392, step = 19501 (0.390 sec)
# INFO:tensorflow:global_step/sec: 248.449
# INFO:tensorflow:loss = 0.00560291, step = 19601 (0.403 sec)
# INFO:tensorflow:global_step/sec: 247.545
# INFO:tensorflow:loss = 0.050964765, step = 19701 (0.403 sec)
# INFO:tensorflow:global_step/sec: 249.489
# INFO:tensorflow:loss = 0.075980976, step = 19801 (0.401 sec)
# INFO:tensorflow:global_step/sec: 262.766
# INFO:tensorflow:loss = 0.014017207, step = 19901 (0.381 sec)
# INFO:tensorflow:global_step/sec: 256.415
# INFO:tensorflow:loss = 0.015571155, step = 20001 (0.390 sec)
# INFO:tensorflow:global_step/sec: 243.734
# INFO:tensorflow:loss = 0.0749249, step = 20101 (0.410 sec)
# INFO:tensorflow:global_step/sec: 228.191
# INFO:tensorflow:loss = 0.0055113174, step = 20201 (0.438 sec)
# INFO:tensorflow:global_step/sec: 247.52
# INFO:tensorflow:loss = 0.04142796, step = 20301 (0.407 sec)
# INFO:tensorflow:global_step/sec: 245.624
# INFO:tensorflow:loss = 0.008889181, step = 20401 (0.405 sec)
# INFO:tensorflow:global_step/sec: 252.517
# INFO:tensorflow:loss = 0.113598965, step = 20501 (0.396 sec)
# INFO:tensorflow:global_step/sec: 254.035
# INFO:tensorflow:loss = 0.05076036, step = 20601 (0.396 sec)
# INFO:tensorflow:global_step/sec: 248.459
# INFO:tensorflow:loss = 0.08113289, step = 20701 (0.400 sec)
# INFO:tensorflow:global_step/sec: 252.194
# INFO:tensorflow:loss = 0.07702904, step = 20801 (0.398 sec)
# INFO:tensorflow:global_step/sec: 270.598
# INFO:tensorflow:loss = 2.6290963, step = 20901 (0.371 sec)
# INFO:tensorflow:global_step/sec: 251.223
# INFO:tensorflow:loss = 0.025767937, step = 21001 (0.399 sec)
# INFO:tensorflow:global_step/sec: 247.095
# INFO:tensorflow:loss = 0.20054227, step = 21101 (0.401 sec)
# INFO:tensorflow:global_step/sec: 241.44
# INFO:tensorflow:loss = 0.02040429, step = 21201 (0.414 sec)
# INFO:tensorflow:global_step/sec: 255.574
# INFO:tensorflow:loss = 0.062065523, step = 21301 (0.391 sec)
# INFO:tensorflow:global_step/sec: 248.259
# INFO:tensorflow:loss = 0.028958187, step = 21401 (0.403 sec)
# INFO:tensorflow:global_step/sec: 259.267
# INFO:tensorflow:loss = 0.010509852, step = 21501 (0.386 sec)
# INFO:tensorflow:global_step/sec: 247.762
# INFO:tensorflow:loss = 0.004413028, step = 21601 (0.407 sec)
# INFO:tensorflow:global_step/sec: 241.588
# INFO:tensorflow:loss = 0.027470155, step = 21701 (0.410 sec)
# INFO:tensorflow:global_step/sec: 248.397
# INFO:tensorflow:loss = 0.0481418, step = 21801 (0.402 sec)
# INFO:tensorflow:global_step/sec: 247.551
# INFO:tensorflow:loss = 0.051976964, step = 21901 (0.404 sec)
# INFO:tensorflow:global_step/sec: 223.717
# INFO:tensorflow:loss = 0.07026685, step = 22001 (0.447 sec)
# INFO:tensorflow:global_step/sec: 239.776
# INFO:tensorflow:loss = 0.05944512, step = 22101 (0.420 sec)
# INFO:tensorflow:global_step/sec: 236.097
# INFO:tensorflow:loss = 0.024427235, step = 22201 (0.421 sec)
# INFO:tensorflow:global_step/sec: 256.633
# INFO:tensorflow:loss = 0.006572947, step = 22301 (0.389 sec)
# INFO:tensorflow:global_step/sec: 238.875
# INFO:tensorflow:loss = 0.105527475, step = 22401 (0.419 sec)
# INFO:tensorflow:global_step/sec: 247.794
# INFO:tensorflow:loss = 0.12882434, step = 22501 (0.409 sec)
# INFO:tensorflow:global_step/sec: 243.8
# INFO:tensorflow:loss = 0.10592834, step = 22601 (0.405 sec)
# INFO:tensorflow:global_step/sec: 240.788
# INFO:tensorflow:loss = 0.0069569014, step = 22701 (0.415 sec)
# INFO:tensorflow:global_step/sec: 240.231
# INFO:tensorflow:loss = 0.13153502, step = 22801 (0.416 sec)
# INFO:tensorflow:global_step/sec: 249.044
# INFO:tensorflow:loss = 0.034467034, step = 22901 (0.402 sec)
# INFO:tensorflow:global_step/sec: 255.327
# INFO:tensorflow:loss = 0.08025208, step = 23001 (0.391 sec)
# INFO:tensorflow:global_step/sec: 260.572
# INFO:tensorflow:loss = 0.13114823, step = 23101 (0.383 sec)
# INFO:tensorflow:global_step/sec: 250.694
# INFO:tensorflow:loss = 0.06116681, step = 23201 (0.399 sec)
# INFO:tensorflow:global_step/sec: 242.428
# INFO:tensorflow:loss = 0.06792017, step = 23301 (0.413 sec)
# INFO:tensorflow:global_step/sec: 248.804
# INFO:tensorflow:loss = 0.0135026565, step = 23401 (0.404 sec)
# INFO:tensorflow:global_step/sec: 260.365
# INFO:tensorflow:loss = 0.0956589, step = 23501 (0.382 sec)
# INFO:tensorflow:global_step/sec: 262.243
# INFO:tensorflow:loss = 0.12133542, step = 23601 (0.382 sec)
# INFO:tensorflow:global_step/sec: 248.214
# INFO:tensorflow:loss = 0.0013654141, step = 23701 (0.405 sec)
# INFO:tensorflow:global_step/sec: 250.282
# INFO:tensorflow:loss = 0.018841213, step = 23801 (0.399 sec)
# INFO:tensorflow:global_step/sec: 262.497
# INFO:tensorflow:loss = 0.094241366, step = 23901 (0.378 sec)
# INFO:tensorflow:global_step/sec: 230.919
# INFO:tensorflow:loss = 0.14672726, step = 24001 (0.433 sec)
# INFO:tensorflow:global_step/sec: 253.203
# INFO:tensorflow:loss = 0.0093771, step = 24101 (0.395 sec)
# INFO:tensorflow:global_step/sec: 249.48
# INFO:tensorflow:loss = 0.029725282, step = 24201 (0.402 sec)
# INFO:tensorflow:global_step/sec: 255.073
# INFO:tensorflow:loss = 0.016635606, step = 24301 (0.392 sec)
# INFO:tensorflow:global_step/sec: 255.312
# INFO:tensorflow:loss = 0.0143728405, step = 24401 (0.391 sec)
# INFO:tensorflow:global_step/sec: 263.18
# INFO:tensorflow:loss = 0.10432, step = 24501 (0.380 sec)
# INFO:tensorflow:global_step/sec: 256.923
# INFO:tensorflow:loss = 0.0067563625, step = 24601 (0.389 sec)
# INFO:tensorflow:global_step/sec: 255.114
# INFO:tensorflow:loss = 0.18372436, step = 24701 (0.392 sec)
# INFO:tensorflow:global_step/sec: 263.073
# INFO:tensorflow:loss = 0.19792059, step = 24801 (0.380 sec)
# INFO:tensorflow:global_step/sec: 250.823
# INFO:tensorflow:loss = 0.0075068753, step = 24901 (0.399 sec)
# INFO:tensorflow:global_step/sec: 256.205
# INFO:tensorflow:loss = 0.10798197, step = 25001 (0.392 sec)
# INFO:tensorflow:global_step/sec: 252.602
# INFO:tensorflow:loss = 0.018964771, step = 25101 (0.394 sec)
# INFO:tensorflow:global_step/sec: 251.554
# INFO:tensorflow:loss = 0.045509506, step = 25201 (0.397 sec)
# INFO:tensorflow:global_step/sec: 259.162
# INFO:tensorflow:loss = 0.08773745, step = 25301 (0.386 sec)
# INFO:tensorflow:global_step/sec: 252.573
# INFO:tensorflow:loss = 0.008801533, step = 25401 (0.395 sec)
# INFO:tensorflow:global_step/sec: 260.771
# INFO:tensorflow:loss = 0.027760442, step = 25501 (0.383 sec)
# INFO:tensorflow:global_step/sec: 256.045
# INFO:tensorflow:loss = 0.006685141, step = 25601 (0.391 sec)
# INFO:tensorflow:global_step/sec: 231.816
# INFO:tensorflow:loss = 0.03716773, step = 25701 (0.431 sec)
# INFO:tensorflow:global_step/sec: 254.011
# INFO:tensorflow:loss = 0.026865182, step = 25801 (0.394 sec)
# INFO:tensorflow:global_step/sec: 253.818
# INFO:tensorflow:loss = 0.19953462, step = 25901 (0.394 sec)
# INFO:tensorflow:global_step/sec: 260.392
# INFO:tensorflow:loss = 0.0179584, step = 26001 (0.384 sec)
# INFO:tensorflow:global_step/sec: 266.3
# INFO:tensorflow:loss = 0.007702557, step = 26101 (0.376 sec)
# INFO:tensorflow:global_step/sec: 250.999
# INFO:tensorflow:loss = 0.014209261, step = 26201 (0.398 sec)
# INFO:tensorflow:global_step/sec: 260.48
# INFO:tensorflow:loss = 0.10590271, step = 26301 (0.388 sec)
# INFO:tensorflow:global_step/sec: 262.527
# INFO:tensorflow:loss = 0.65321034, step = 26401 (0.377 sec)
# INFO:tensorflow:global_step/sec: 256.943
# INFO:tensorflow:loss = 0.025907276, step = 26501 (0.389 sec)
# INFO:tensorflow:global_step/sec: 257.699
# INFO:tensorflow:loss = 0.08778344, step = 26601 (0.388 sec)
# INFO:tensorflow:global_step/sec: 253.046
# INFO:tensorflow:loss = 0.020006606, step = 26701 (0.395 sec)
# INFO:tensorflow:global_step/sec: 249.108
# INFO:tensorflow:loss = 0.007964298, step = 26801 (0.401 sec)
# INFO:tensorflow:global_step/sec: 261.828
# INFO:tensorflow:loss = 0.035460353, step = 26901 (0.383 sec)
# INFO:tensorflow:global_step/sec: 251.262
# INFO:tensorflow:loss = 0.042773817, step = 27001 (0.397 sec)
# INFO:tensorflow:global_step/sec: 254.112
# INFO:tensorflow:loss = 0.0069698673, step = 27101 (0.396 sec)
# INFO:tensorflow:global_step/sec: 228.026
# INFO:tensorflow:loss = 0.010562147, step = 27201 (0.444 sec)
# INFO:tensorflow:global_step/sec: 240.272
# INFO:tensorflow:loss = 0.031674676, step = 27301 (0.408 sec)
# INFO:tensorflow:global_step/sec: 236.935
# INFO:tensorflow:loss = 0.057473175, step = 27401 (0.422 sec)
# INFO:tensorflow:global_step/sec: 247.826
# INFO:tensorflow:loss = 0.015002531, step = 27501 (0.403 sec)
# INFO:tensorflow:global_step/sec: 255.172
# INFO:tensorflow:loss = 0.15934823, step = 27601 (0.395 sec)
# INFO:tensorflow:global_step/sec: 246.897
# INFO:tensorflow:loss = 0.037533022, step = 27701 (0.403 sec)
# INFO:tensorflow:global_step/sec: 239.913
# INFO:tensorflow:loss = 0.105863295, step = 27801 (0.418 sec)
# INFO:tensorflow:global_step/sec: 241.286
# INFO:tensorflow:loss = 0.08045051, step = 27901 (0.413 sec)
# INFO:tensorflow:global_step/sec: 216.555
# INFO:tensorflow:loss = 0.008456194, step = 28001 (0.461 sec)
# INFO:tensorflow:global_step/sec: 256.289
# INFO:tensorflow:loss = 0.019020129, step = 28101 (0.394 sec)
# INFO:tensorflow:global_step/sec: 239.788
# INFO:tensorflow:loss = 0.019566834, step = 28201 (0.413 sec)
# INFO:tensorflow:global_step/sec: 241.516
# INFO:tensorflow:loss = 0.009943353, step = 28301 (0.414 sec)
# INFO:tensorflow:global_step/sec: 242.336
# INFO:tensorflow:loss = 0.026787233, step = 28401 (0.416 sec)
# INFO:tensorflow:global_step/sec: 240.731
# INFO:tensorflow:loss = 0.04291192, step = 28501 (0.412 sec)
# INFO:tensorflow:global_step/sec: 249.498
# INFO:tensorflow:loss = 0.050950173, step = 28601 (0.402 sec)
# INFO:tensorflow:global_step/sec: 236.063
# INFO:tensorflow:loss = 0.016800294, step = 28701 (0.423 sec)
# INFO:tensorflow:global_step/sec: 255.18
# INFO:tensorflow:loss = 0.06313839, step = 28801 (0.392 sec)
# INFO:tensorflow:global_step/sec: 256.544
# INFO:tensorflow:loss = 0.012822639, step = 28901 (0.391 sec)
# INFO:tensorflow:global_step/sec: 246.012
# INFO:tensorflow:loss = 0.025898457, step = 29001 (0.405 sec)
# INFO:tensorflow:global_step/sec: 237.229
# INFO:tensorflow:loss = 0.017082501, step = 29101 (0.422 sec)
# INFO:tensorflow:global_step/sec: 236.966
# INFO:tensorflow:loss = 0.03483788, step = 29201 (0.425 sec)
# INFO:tensorflow:global_step/sec: 248.101
# INFO:tensorflow:loss = 0.010633165, step = 29301 (0.400 sec)
# INFO:tensorflow:global_step/sec: 247.882
# INFO:tensorflow:loss = 0.065502845, step = 29401 (0.404 sec)
# INFO:tensorflow:global_step/sec: 244.588
# INFO:tensorflow:loss = 0.12949347, step = 29501 (0.412 sec)
# INFO:tensorflow:global_step/sec: 257.202
# INFO:tensorflow:loss = 0.013967583, step = 29601 (0.385 sec)
# INFO:tensorflow:global_step/sec: 248.268
# INFO:tensorflow:loss = 0.064615384, step = 29701 (0.402 sec)
# INFO:tensorflow:global_step/sec: 260.241
# INFO:tensorflow:loss = 0.038201705, step = 29801 (0.384 sec)
# INFO:tensorflow:global_step/sec: 250.947
# INFO:tensorflow:loss = 0.011783571, step = 29901 (0.400 sec)
# INFO:tensorflow:global_step/sec: 243.507
# INFO:tensorflow:loss = 0.0075815124, step = 30001 (0.409 sec)
# INFO:tensorflow:global_step/sec: 255.672
# INFO:tensorflow:loss = 0.11359713, step = 30101 (0.391 sec)
# INFO:tensorflow:global_step/sec: 255.22
# INFO:tensorflow:loss = 0.0029828926, step = 30201 (0.391 sec)
# INFO:tensorflow:global_step/sec: 251.799
# INFO:tensorflow:loss = 0.059283108, step = 30301 (0.397 sec)
# INFO:tensorflow:global_step/sec: 257.732
# INFO:tensorflow:loss = 0.004566091, step = 30401 (0.390 sec)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-72673cc4188e> in <module>()
#       5 input_fn = tf.estimator.inputs.numpy_input_fn(
#       6     x={"X": X_train}, y=y_train, num_epochs=40, batch_size=50, shuffle=True)
# ----> 7 dnn_clf.train(input_fn=input_fn)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     356
#     357       saving_listeners = _check_listeners_type(saving_listeners)
# --> 358       loss = self._train_model(input_fn, hooks, saving_listeners)
#     359       logging.info('Loss for final step: %s.', loss)
#     360       return self
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1122       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1123     else:
# -> 1124       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1125
#    1126   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1156       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1157                                              hooks, global_step_tensor,
# -> 1158                                              saving_listeners)
#    1159
#    1160   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1405       any_step_done = False
#    1406       while not mon_sess.should_stop():
# -> 1407         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1408         any_step_done = True
#    1409     if not any_step_done:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     674                           feed_dict=feed_dict,
#     675                           options=options,
# --> 676                           run_metadata=run_metadata)
#     677
#     678   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1169                               feed_dict=feed_dict,
#    1170                               options=options,
# -> 1171                               run_metadata=run_metadata)
#    1172       except _PREEMPTION_ERRORS as e:
#    1173         logging.info('An error was raised. This may be due to a preemption in '
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1253   def run(self, *args, **kwargs):
#    1254     try:
# -> 1255       return self._sess.run(*args, **kwargs)
#    1256     except _PREEMPTION_ERRORS:
#    1257       raise
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1325                                   feed_dict=feed_dict,
#    1326                                   options=options,
# -> 1327                                   run_metadata=run_metadata)
#    1328
#    1329     for hook in self._hooks:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1089
#    1090   def run(self, *args, **kwargs):
# -> 1091     return self._sess.run(*args, **kwargs)
#    1092
#    1093   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
test_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_test}, y=y_test, shuffle=False)
eval_results = dnn_clf.evaluate(input_fn=test_input_fn)

# %%
eval_results

# %%
y_pred_iter = dnn_clf.predict(input_fn=test_input_fn)
y_pred = list(y_pred_iter)
y_pred[0]

# %% [markdown]
# ## Using plain TensorFlow

# %%
import tensorflow as tf

n_inputs = 28*28  # MNIST
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name="kernel")
        b = tf.Variable(tf.zeros([n_neurons]), name="bias")
        Z = tf.matmul(X, W) + b
        if activation is not None:
            return activation(Z)
        else:
            return Z

# %%
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, name="hidden1",
                           activation=tf.nn.relu)
    hidden2 = neuron_layer(hidden1, n_hidden2, name="hidden2",
                           activation=tf.nn.relu)
    logits = neuron_layer(hidden2, n_outputs, name="outputs")

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                              logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 40
batch_size = 50

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_val = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Batch accuracy:", acc_batch, "Val accuracy:", acc_val)

    save_path = saver.save(sess, "./my_model_final.ckpt")

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_final.ckpt") # or better, use save_path
    X_new_scaled = X_test[:20]
    Z = logits.eval(feed_dict={X: X_new_scaled})
    y_pred = np.argmax(Z, axis=1)

# %%
print("Predicted classes:", y_pred)
print("Actual classes:   ", y_test[:20])

# %%
from tensorflow_graph_in_jupyter import show_graph

# %%
show_graph(tf.get_default_graph())

# %% [markdown]
# ## Using `dense()` instead of `neuron_layer()`

# %% [markdown]
# Note: previous releases of the book used `tensorflow.contrib.layers.fully_connected()` rather than `tf.layers.dense()` (which did not exist when this chapter was written). It is now preferable to use `tf.layers.dense()`, because anything in the contrib module may change or be deleted without notice. The `dense()` function is almost identical to the `fully_connected()` function, except for a few minor differences:
# * several parameters are renamed: `scope` becomes `name`, `activation_fn` becomes `activation` (and similarly the `_fn` suffix is removed from other parameters such as `normalizer_fn`), `weights_initializer` becomes `kernel_initializer`, etc.
# * the default `activation` is now `None` rather than `tf.nn.relu`.
# * a few more differences are presented in chapter 11.

# %%
n_inputs = 28*28  # MNIST
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")

# %%
with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1",
                              activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2",
                              activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")
    y_proba = tf.nn.softmax(logits)
# Out:
# WARNING:tensorflow:From <ipython-input-17-28239acea1fc>:3: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 20
n_batches = 50

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_valid = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Batch accuracy:", acc_batch, "Validation accuracy:", acc_valid)

    save_path = saver.save(sess, "./my_model_final.ckpt")
# Out:
# 0 Batch accuracy: 0.9 Validation accuracy: 0.9024
# 1 Batch accuracy: 0.92 Validation accuracy: 0.9254
# 2 Batch accuracy: 0.94 Validation accuracy: 0.9372
# 3 Batch accuracy: 0.9 Validation accuracy: 0.9416
# 4 Batch accuracy: 0.94 Validation accuracy: 0.9472
# 5 Batch accuracy: 0.94 Validation accuracy: 0.951
# 6 Batch accuracy: 1.0 Validation accuracy: 0.9548
# 7 Batch accuracy: 0.94 Validation accuracy: 0.961
# 8 Batch accuracy: 0.96 Validation accuracy: 0.9622
# 9 Batch accuracy: 0.94 Validation accuracy: 0.9648
# 10 Batch accuracy: 0.92 Validation accuracy: 0.9654
# 11 Batch accuracy: 0.98 Validation accuracy: 0.9668
# 12 Batch accuracy: 0.98 Validation accuracy: 0.9686
# 13 Batch accuracy: 0.98 Validation accuracy: 0.9702
# 14 Batch accuracy: 1.0 Validation accuracy: 0.9696
# 15 Batch accuracy: 0.94 Validation accuracy: 0.9718
# 16 Batch accuracy: 0.98 Validation accuracy: 0.9726
# 17 Batch accuracy: 1.0 Validation accuracy: 0.9728
# 18 Batch accuracy: 0.98 Validation accuracy: 0.9752
# 19 Batch accuracy: 0.96 Validation accuracy: 0.9754

# %%
show_graph(tf.get_default_graph())

# %% [markdown]
# # Exercise solutions

# %% [markdown]
# ## 1. to 8.

# %% [markdown]
# See appendix A.

# %% [markdown]
# ## 9.

# %% [markdown]
# _Train a deep MLP on the MNIST dataset and see if you can get over 98% precision. Just like in the last exercise of chapter 9, try adding all the bells and whistles (i.e., save checkpoints, restore the last checkpoint in case of an interruption, add summaries, plot learning curves using TensorBoard, and so on)._

# %% [markdown]
# First let's create the deep net. It's exactly the same as earlier, with just one addition: we add a `tf.summary.scalar()` to track the loss and the accuracy during training, so we can view nice learning curves using TensorBoard.

# %%
n_inputs = 28*28  # MNIST
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")

# %%
with tf.name_scope("dnn"):
    hidden1 = tf.layers.dense(X, n_hidden1, name="hidden1",
                              activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name="hidden2",
                              activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name="outputs")

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")
    loss_summary = tf.summary.scalar('log_loss', loss)

# %%
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    accuracy_summary = tf.summary.scalar('accuracy', accuracy)

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# Now we need to define the directory to write the TensorBoard logs to:

# %%
from datetime import datetime

def log_dir(prefix=""):
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    root_logdir = "tf_logs"
    if prefix:
        prefix += "-"
    name = prefix + "run-" + now
    return "{}/{}/".format(root_logdir, name)

# %%
logdir = log_dir("mnist_dnn")

# %% [markdown]
# Now we can create the `FileWriter` that we will use to write the TensorBoard logs:

# %%
file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

# %% [markdown]
# Hey! Why don't we implement early stopping? For this, we are going to need to use the validation set.

# %%
m, n = X_train.shape

# %%
n_epochs = 10001
batch_size = 50
n_batches = int(np.ceil(m / batch_size))

checkpoint_path = "/tmp/my_deep_mnist_model.ckpt"
checkpoint_epoch_path = checkpoint_path + ".epoch"
final_model_path = "./my_deep_mnist_model"

best_loss = np.infty
epochs_without_progress = 0
max_epochs_without_progress = 50

with tf.Session() as sess:
    if os.path.isfile(checkpoint_epoch_path):
        # if the checkpoint file exists, restore the model and load the epoch number
        with open(checkpoint_epoch_path, "rb") as f:
            start_epoch = int(f.read())
        print("Training was interrupted. Continuing at epoch", start_epoch)
        saver.restore(sess, checkpoint_path)
    else:
        start_epoch = 0
        sess.run(init)

    for epoch in range(start_epoch, n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        accuracy_val, loss_val, accuracy_summary_str, loss_summary_str = sess.run([accuracy, loss, accuracy_summary, loss_summary], feed_dict={X: X_valid, y: y_valid})
        file_writer.add_summary(accuracy_summary_str, epoch)
        file_writer.add_summary(loss_summary_str, epoch)
        if epoch % 5 == 0:
            print("Epoch:", epoch,
                  "\tValidation accuracy: {:.3f}%".format(accuracy_val * 100),
                  "\tLoss: {:.5f}".format(loss_val))
            saver.save(sess, checkpoint_path)
            with open(checkpoint_epoch_path, "wb") as f:
                f.write(b"%d" % (epoch + 1))
            if loss_val < best_loss:
                saver.save(sess, final_model_path)
                best_loss = loss_val
            else:
                epochs_without_progress += 5
                if epochs_without_progress > max_epochs_without_progress:
                    print("Early stopping")
                    break

# %%
os.remove(checkpoint_epoch_path)

# %%
with tf.Session() as sess:
    saver.restore(sess, final_model_path)
    accuracy_val = accuracy.eval(feed_dict={X: X_test, y: y_test})

# %%
accuracy_val
